# %% [markdown]
# IMPORT LIBRARIES

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import os

# Importing Deep Learning Libraries

from keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator, MaxPooling2D
from tensorflow.keras.layers import Dense,Input,Dropout,GlobalAveragePooling2D,Flatten,Conv2D,BatchNormalization,Activation
from keras.models import Model,Sequential
from keras.optimizers import Adam,SGD,RMSprop

# %% [markdown]
# DISPLAYING IMAGES

# %%
picture_size = 48
folder_path = "C:/Users/danny/OneDrive/Dokumen/VSCode/Kecerdasan Buatan/images"

# %%
expression = 'angry'

plt.figure(figsize= (12,12))
for i in range(1, 10, 1):
    plt.subplot(3,3,i)
    img = load_img(folder_path+"/train/"+expression+"/"+
                  os.listdir(folder_path + "/train/" + expression)[i], target_size=(picture_size, picture_size))
    plt.imshow(img)   
plt.show()

# %% [markdown]
# MAKING TRAINING AND VALIDATION DATA

# %%
batch_size  = 128

datagen_train  = ImageDataGenerator()
datagen_val = ImageDataGenerator()

train_set = datagen_train.flow_from_directory(folder_path+"/train",
                                              target_size = (picture_size,picture_size),
                                              color_mode = "grayscale",
                                              batch_size=batch_size,
                                              class_mode='categorical',
                                              shuffle=True)


test_set = datagen_val.flow_from_directory(folder_path+"/test",
                                              target_size = (picture_size,picture_size),
                                              color_mode = "grayscale",
                                              batch_size=batch_size,
                                              class_mode='categorical',
                                              shuffle=False)
# Out:
# Found 28821 images belonging to 7 classes.
# Found 7066 images belonging to 7 classes.

# %% [markdown]
# MODEL BUILDING

# %%
from keras.optimizers import Adam,SGD,RMSprop


no_of_classes = 7

model = Sequential()

# Input layer
model.add(Input(shape=(48, 48, 1)))

# 1st CNN layer
model.add(Conv2D(64, (3, 3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

#2nd CNN layer
model.add(Conv2D(128,(5,5),padding = 'same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout (0.25))

#3rd CNN layer
model.add(Conv2D(512,(3,3),padding = 'same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout (0.25))

#4th CNN layer
model.add(Conv2D(512,(3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())

#Fully connected 1st layer
model.add(Dense(256))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))


# Fully connected layer 2nd layer
model.add(Dense(512))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))

model.add(Dense(no_of_classes, activation='softmax'))



opt = Adam(learning_rate=0.0001)
model.compile(optimizer=opt,loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)                    │ (None, 48, 48, 64)          │             640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 48, 48, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation (Activation)              │ (None, 48, 48, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 24, 24, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 24, 24, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 24, 24, 128)         │         204,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 24, 24, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_1 (Activation)            │ (None, 24, 24, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 12, 12, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_7 (Dropout)                  │ (None, 12, 12, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 12, 12, 512)         │         590,336 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 12, 12, 512)         │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_2 (Activation)            │ (None, 12, 12, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_6 (MaxPooling2D)       │ (None, 6, 6, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_8 (Dropout)                  │ (None, 6, 6, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 6, 6, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 6, 6, 512)           │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_3 (Activation)            │ (None, 6, 6, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_7 (MaxPooling2D)       │ (None, 3, 3, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_9 (Dropout)                  │ (None, 3, 3, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 4608)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 256)                 │       1,179,904 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_4 (Activation)            │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_10 (Dropout)                 │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 512)                 │         131,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_5 (Activation)            │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_11 (Dropout)                 │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 7)                   │           3,591 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,478,727 (17.08 MB)
#  Trainable params: 4,474,759 (17.07 MB)
#  Non-trainable params: 3,968 (15.50 KB)

# %% [markdown]
# FITTING THE MODEL WITH TRAINING AND VALIDATION DATA

# %%
from keras.callbacks import ModelCheckpoint

epochs = 48

checkpoint = ModelCheckpoint("model_weights.keras", monitor='val_acc', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

history = model.fit(train_set,
                    steps_per_epoch=train_set.n // train_set.batch_size,
                    epochs=epochs,
                    validation_data=test_set,
                    validation_steps=test_set.n // test_set.batch_size,
                    callbacks=callbacks_list)
# Out:
# Epoch 1/48
# C:\Users\danny\AppData\Roaming\Python\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 206s 893ms/step - accuracy: 0.2236 - loss: 2.0701 - val_accuracy: 0.3159 - val_loss: 1.7137
# Epoch 2/48
# C:\Users\danny\AppData\Roaming\Python\Python311\site-packages\keras\src\callbacks\model_checkpoint.py:206: UserWarning: Can save best model only with val_acc available, skipping.
#   self._save_model(epoch=epoch, batch=None, logs=logs)
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 515us/step - accuracy: 0.2031 - loss: 2.0111 - val_accuracy: 0.0769 - val_loss: 2.3175
# Epoch 3/48
# C:\ProgramData\anaconda3\Lib\contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 209s 930ms/step - accuracy: 0.2944 - loss: 1.8181 - val_accuracy: 0.3526 - val_loss: 1.6739
# Epoch 4/48
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 484us/step - accuracy: 0.2656 - loss: 1.9384 - val_accuracy: 0.2692 - val_loss: 2.4357
# Epoch 5/48
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 199s 885ms/step - accuracy: 0.3414 - loss: 1.7182 - val_accuracy: 0.3814 - val_loss: 1.6393
# Epoch 6/48
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 366us/step - accuracy: 0.3984 - loss: 1.6356 - val_accuracy: 0.3462 - val_loss: 2.1881
# Epoch 7/48
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 192s 854ms/step - accuracy: 0.3631 - loss: 1.6615 - val_accuracy: 0.3834 - val_loss: 1.6584
# Epoch 8/48
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 388us/step - accuracy: 0.3672 - loss: 1.6183 - val_accuracy: 0.4231 - val_loss: 2.2013
# Epoch 9/48
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 191s 850ms/step - accuracy: 0.3872 - loss: 1.5895 - val_accuracy: 0.4246 - val_loss: 1.5156
# Epoch 10/48
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 379us/step - accuracy: 0.4062 - loss: 1.6874 - val_accuracy: 0.5769 - val_loss: 1.5239
# Epoch 11/48
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 199s 882ms/step - accuracy: 0.4075 - loss: 1.5408 - val_accuracy: 0.4355 - val_loss: 1.4662
# Epoch 12/48
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 441us/step - accuracy: 0.3984 - loss: 1.5638 - val_accuracy: 0.5385 - val_loss: 1.4887
# Epoch 13/48
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 201s 893ms/step - accuracy: 0.4273 - loss: 1.4984 - val_accuracy: 0.4442 - val_loss: 1.4612
# Epoch 14/48
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 449us/step - accuracy: 0.4297 - loss: 1.4339 - val_accuracy: 0.5385 - val_loss: 1.6767
# Epoch 15/48
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 199s 885ms/step - accuracy: 0.4394 - loss: 1.4471 - val_accuracy: 0.4801 - val_loss: 1.3510
# Epoch 16/48
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 421us/step - accuracy: 0.5391 - loss: 1.3023 - val_accuracy: 0.6154 - val_loss: 1.1089
# Epoch 17/48
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 201s 892ms/step - accuracy: 0.4660 - loss: 1.4011 - val_accuracy: 0.4847 - val_loss: 1.3580
# Epoch 18/48
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 442us/step - accuracy: 0.4297 - loss: 1.4668 - val_accuracy: 0.5769 - val_loss: 1.5263
# Epoch 19/48
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 204s 907ms/step - accuracy: 0.4762 - loss: 1.3727 - val_accuracy: 0.5129 - val_loss: 1.2792
# Epoch 20/48
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 391us/step - accuracy: 0.4219 - loss: 1.5087 - val_accuracy: 0.6538 - val_loss: 0.8432
# Epoch 21/48
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 200s 889ms/step - accuracy: 0.4923 - loss: 1.3301 - val_accuracy: 0.5209 - val_loss: 1.2517
# Epoch 22/48
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 412us/step - accuracy: 0.5000 - loss: 1.1849 - val_accuracy: 0.6154 - val_loss: 1.1508
# Epoch 23/48
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 200s 890ms/step - accuracy: 0.5015 - loss: 1.2927 - val_accuracy: 0.5243 - val_loss: 1.2503
# Epoch 24/48
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 399us/step - accuracy: 0.4766 - loss: 1.3265 - val_accuracy: 0.6538 - val_loss: 1.1142
# Epoch 25/48
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 204s 904ms/step - accuracy: 0.5121 - loss: 1.2679 - val_accuracy: 0.5402 - val_loss: 1.2172
# Epoch 26/48
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 416us/step - accuracy: 0.6094 - loss: 1.2298 - val_accuracy: 0.6923 - val_loss: 0.8917
# Epoch 27/48
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 207s 919ms/step - accuracy: 0.5211 - loss: 1.2534 - val_accuracy: 0.5399 - val_loss: 1.2097
# Epoch 28/48
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 434us/step - accuracy: 0.5078 - loss: 1.2826 - val_accuracy: 0.6923 - val_loss: 0.9726
# Epoch 29/48
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 222s 984ms/step - accuracy: 0.5372 - loss: 1.2192 - val_accuracy: 0.5517 - val_loss: 1.1749
# Epoch 30/48
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 389us/step - accuracy: 0.4375 - loss: 1.1923 - val_accuracy: 0.6923 - val_loss: 0.7957
# Epoch 31/48
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 201s 890ms/step - accuracy: 0.5460 - loss: 1.1935 - val_accuracy: 0.5524 - val_loss: 1.1881
# Epoch 32/48
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 410us/step - accuracy: 0.5859 - loss: 1.1748 - val_accuracy: 0.6538 - val_loss: 1.1325
# Epoch 33/48
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 204s 906ms/step - accuracy: 0.5542 - loss: 1.1732 - val_accuracy: 0.5629 - val_loss: 1.1540
# Epoch 34/48
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 714us/step - accuracy: 0.4766 - loss: 1.3792 - val_accuracy: 0.8077 - val_loss: 0.7060
# Epoch 35/48
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 216s 957ms/step - accuracy: 0.5660 - loss: 1.1489 - val_accuracy: 0.5703 - val_loss: 1.1380
# Epoch 36/48
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 380us/step - accuracy: 0.5547 - loss: 1.1853 - val_accuracy: 0.7692 - val_loss: 0.7355
# Epoch 37/48
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 204s 907ms/step - accuracy: 0.5685 - loss: 1.1370 - val_accuracy: 0.5689 - val_loss: 1.1522
# Epoch 38/48
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 396us/step - accuracy: 0.5469 - loss: 1.1590 - val_accuracy: 0.7308 - val_loss: 0.9314
# Epoch 39/48
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 216s 959ms/step - accuracy: 0.5765 - loss: 1.1098 - val_accuracy: 0.5845 - val_loss: 1.1175
# Epoch 40/48
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 466us/step - accuracy: 0.5625 - loss: 1.1397 - val_accuracy: 0.8077 - val_loss: 0.7308
# Epoch 41/48
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 207s 918ms/step - accuracy: 0.5823 - loss: 1.0920 - val_accuracy: 0.5770 - val_loss: 1.1246
# Epoch 42/48
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 430us/step - accuracy: 0.5469 - loss: 1.0979 - val_accuracy: 0.8462 - val_loss: 0.6980
# Epoch 43/48
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 203s 901ms/step - accuracy: 0.5921 - loss: 1.0791 - val_accuracy: 0.5859 - val_loss: 1.1136
# Epoch 44/48
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 444us/step - accuracy: 0.6016 - loss: 1.2592 - val_accuracy: 0.8077 - val_loss: 0.7792
# Epoch 45/48
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 202s 895ms/step - accuracy: 0.6020 - loss: 1.0592 - val_accuracy: 0.6054 - val_loss: 1.0742
# Epoch 46/48
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 404us/step - accuracy: 0.5781 - loss: 1.1059 - val_accuracy: 0.8077 - val_loss: 0.8147
# Epoch 47/48
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 196s 871ms/step - accuracy: 0.6059 - loss: 1.0500 - val_accuracy: 0.5912 - val_loss: 1.1068
# Epoch 48/48
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 379us/step - accuracy: 0.6172 - loss: 1.0336 - val_accuracy: 0.6923 - val_loss: 0.9682

# %% [markdown]
# SAVING MODEL

# %%
model.save("C:/Users/danny/OneDrive/Dokumen/VSCode/Kecerdasan Buatan/model.keras")

# %% [markdown]
# PLOTTING ACCURACY & LOSS

# %%
plt.figure(figsize=(20,10))
plt.subplot(1, 2, 1)
plt.suptitle('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend(loc='upper right')

plt.subplot(1, 2, 2)
plt.ylabel('Accuracy', fontsize=16)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.show()
